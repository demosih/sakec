# %%
# !pip install -U pgmpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 18.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from google.colab import files
from pgmpy.models import DiscreteBayesianNetwork  # new name
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.inference import VariableElimination
from pgmpy.factors.discrete import TabularCPD
import io

# %%
model = DiscreteBayesianNetwork([
    ('Make', 'Model'),
    ('Model', 'Variant'),
    ('Variant', 'Ex-Showroom_Price')
])
print("✅ Discrete Bayesian Network created successfully!")
# Out:
# ✅ Discrete Bayesian Network created successfully!

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2426922694.py in <cell line: 0>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
model.fit(data, estimator=MaximumLikelihoodEstimator)
print("✅ Model trained successfully!")
# Out:
# ✅ Model trained successfully!

# %%
infer = VariableElimination(model)
print("✅ Performing inference on variable Ex-Showroom_Price (example):")
print(infer.query(variables=['Ex-Showroom_Price']))
# Out:
# ✅ Performing inference on variable Ex-Showroom_Price (example):
# +-------------------------------------+--------------------------+
# | Ex-Showroom_Price                   |   phi(Ex-Showroom_Price) |
# +=====================================+==========================+
# | Ex-Showroom_Price(Rs. 1,01,44,987)  |                   0.0008 |
# +-------------------------------------+--------------------------+
# | Ex-Showroom_Price(Rs. 1,02,05,494)  |                   0.0008 |
# +-------------------------------------+--------------------------+
# | Ex-Showroom_Price(Rs. 1,02,50,000)  |                   0.0008 |
# +-------------------------------------+--------------------------+
# | Ex-Showroom_Price(Rs. 1,03,73,732)  |                   0.0008 |
# +-------------------------------------+--------------------------+
# | Ex-Showroom_Price(Rs. 1,04,19,200)  |                   0.0008 |
# +-------------------------------------+--------------------------+
# ...
