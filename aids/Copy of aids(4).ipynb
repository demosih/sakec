# %%
 # !pip install scikit-fuzzy
import pandas as pd
import numpy as np
import skfuzzy as fuzz
from google.colab import files
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.8/920.8 kB 15.6 MB/s eta 0:00:00
# ...

# %%
data = pd.read_csv("/content/cars.csv")
data.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
 subset = data.iloc[0:10, 0:3]   # first 10 rows, 3 columns
print(subset)
print(data['Model'].iloc[5])  # single element
# Out:
#      Make      Model  Variant
# 0    Tata  Nano Genx       Xt
# 1    Tata  Nano Genx       Xe
# 2    Tata  Nano Genx  Emax Xm
# 3    Tata  Nano Genx      Xta
# 4    Tata  Nano Genx       Xm
# 5    Tata  Nano Genx      Xma
# 6  Datsun    Redi-Go        D
# 7  Datsun    Redi-Go        T
# 8  Datsun    Redi-Go        A
# 9  Datsun    Redi-Go        S
# Nano Genx

# %%
 x = np.arange(0, 11, 1)
low = fuzz.trimf(x, [0, 0, 5])
medium = fuzz.trimf(x, [0, 5, 10])
high = fuzz.trimf(x, [5, 10, 10])

import matplotlib.pyplot as plt
plt.figure()
plt.plot(x, low, 'b', label='Low')
plt.plot(x, medium, 'g', label='Medium')
plt.plot(x, high, 'r', label='High')
plt.title('Fuzzy Membership Functions')
plt.legend()
plt.show()

# %%
 value = 6
low_val = fuzz.interp_membership(x, low, value)
med_val = fuzz.interp_membership(x, medium, value)
high_val = fuzz.interp_membership(x, high, value)
print("Low:", low_val, "Medium:", med_val, "High:", high_val)
# Out:
# Low: 0.0 Medium: 0.8 High: 0.2
